# %%
import pandas as pd

# %%
df = pd.read_csv('/content/mobile_prices_2023.csv')
df.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# ...

# %%
df.shape
# Out:
# (1836, 11)

# %%
df.describe()
# Out:
#         Rating ?/5
# count  1836.000000
# mean      4.210512
# std       0.543912
# min       0.000000
# 25%       4.200000
# 50%       4.300000
# 75%       4.400000
# max       4.800000

# %%
df.dtypes
# Out:
# Phone Name            object
# Rating ?/5           float64
# Number of Ratings     object
# RAM                   object
# ROM/Storage           object
# Back/Rare Camera      object
# Front Camera          object
# Battery               object
# Processor             object
# Price in INR          object
# Date of Scraping      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# RAM                    0
# ROM/Storage          174
# Back/Rare Camera       9
# Front Camera         401
# Battery               10
# Processor             55
# Price in INR           0
# Date of Scraping       0
# dtype: int64

# %%
df2 = df.dropna()
df2.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# ...

# %%
df2.shape
# Out:
# (1291, 11)

# %%
df2.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# Date of Scraping     0
# dtype: int64

# %% [markdown]
# **WORKING ON RAM COLUMN**

# %%
df2['RAM'].unique()
# Out:
# array(['2 GB RAM', '4 GB RAM', '6 GB RAM', '3 GB RAM', '8 GB RAM',
#        '12 GB RAM', '8 MB RAM', '1 GB RAM', '16 MB RAM', '512 MB RAM',
#        '1.5 GB RAM'], dtype=object)

# %%
unwanted_elements = ['128 GB ROM', '64 GB ROM', '256 GB ROM', '512 GB ROM',
       '16 GB ROM', '32 GB ROM', '8 GB ROM', '1 TB ROM', 'NA ROM',
       'Expandable Upto 16 GB','8 MB RAM', '0 MB ROM', '4 MB RAM',
       '0.53 RAM', '153 MB RAM', 'NA MB ROM', '1 GB RAM', '16 MB RAM',
       '3.81 cm (1.5 inch) Display', 'cm Display', '32 MB RAM',
       '128 MB RAM', '16 MB ROM', '48 MB RAM', '0.046875 GB RAM',
       '32 MB ROM', '64 MB RAM', '8 MB ROM', '768 MB RAM', '1 MB RAM',
       '16 GB RAM', '512 MB RAM', '1.5 GB RAM', '1 MB ROM', '256 MB RAM',
       '60 MB ROM', 'Expandable Upto 2 GB', '2 MB ROM', '80 MB ROM',
       '50 MB ROM']

# %%
df2['RAM'] = df2['RAM'].replace(unwanted_elements, pd.NA)
df2.head()
# Out:
# <ipython-input-21-7b938503ed5c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['RAM'] = df2['RAM'].replace(unwanted_elements, pd.NA)
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# ...

# %%
df2.isnull().sum()
# Out:
# Phone Name            0
# Rating ?/5            0
# Number of Ratings     0
# RAM                  19
# ROM/Storage           0
# Back/Rare Camera      0
# Front Camera          0
# Battery               0
# Processor             0
# Price in INR          0
# Date of Scraping      0
# dtype: int64

# %%
df3 = df2.dropna()
df3.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# ...

# %%
df3.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# Date of Scraping     0
# dtype: int64

# %%
df3['RAM'].unique()
# Out:
# array(['2 GB RAM', '4 GB RAM', '6 GB RAM', '3 GB RAM', '8 GB RAM',
#        '12 GB RAM'], dtype=object)

# %%
category_mapping = {'2 GB RAM': 2, '4 GB RAM': 4, '6 GB RAM': 6,'8 GB RAM': 8, '3 GB RAM': 3, '12 GB RAM': 12}
df3['RAM'] = df3['RAM'].map(category_mapping)
df3.head()
# Out:
# <ipython-input-26-f7cb2d9c299e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['RAM'] = df3['RAM'].map(category_mapping)
#                       Phone Name  Rating ?/5 Number of Ratings  RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561    2
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128    4
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175    4
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621    4
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175    4
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# ...

# %%
df3['RAM'].unique()
# Out:
# array([ 2,  4,  6,  3,  8, 12])

# %%
df.dtypes
# Out:
# Phone Name            object
# Rating ?/5           float64
# Number of Ratings     object
# RAM                   object
# ROM/Storage           object
# Back/Rare Camera      object
# Front Camera          object
# Battery               object
# Processor             object
# Price in INR          object
# Date of Scraping      object
# dtype: object

# %%
df4 = df3.copy()
df4
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %% [markdown]
# **WORKING ON ROM/Storage Column**

# %%
column_to_drop = 'Date of Scraping'
df4 = df4.drop(column_to_drop, axis=1)
df4
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2            33,561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3            15,175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2            22,621
# 4                POCO C51 (Power Black, 64 GB)         4.3            15,175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3            25,582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3            25,582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3            25,582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2             7,117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3            15,701
#
# ...

# %%
df4['ROM/Storage'].unique()
# Out:
# array(['32 GB ROM', '64 GB ROM', '128 GB ROM', '256 GB ROM', '512 GB ROM',
#        '16 GB ROM', '8 GB ROM'], dtype=object)

# %%
category_mapping = {'32 GB ROM': 32, '64 GB ROM':64, '128 GB ROM':128, '256 GB ROM':256, '512 GB ROM':512,
       '16 GB ROM':16, '8 GB ROM':8}
df4['ROM/Storage'] = df4['ROM/Storage'].map(category_mapping)
df4.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings  RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561    2
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128    4
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175    4
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621    4
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175    4
#
#    ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0           32        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1           64             50MP + 2MP  8MP Front Camera  5000 mAh
# 2           64   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3           64  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4           64   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# ...

# %%
df4['ROM/Storage'].unique()
# Out:
# array([ 32,  64, 128, 256, 512,  16,   8])

# %%
df4.dtypes
# Out:
# Phone Name            object
# Rating ?/5           float64
# Number of Ratings     object
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera      object
# Front Camera          object
# Battery               object
# Processor             object
# Price in INR          object
# dtype: object

# %% [markdown]
# **WORKING ON Number of Ratings Column**

# %%
column_to_clean = 'Number of Ratings'
df4[column_to_clean] = df4[column_to_clean].str.replace(',', '')
df4
# Out:
#                                     Phone Name  Rating ?/5 Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2             33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2             77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3             15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2             22621
# 4                POCO C51 (Power Black, 64 GB)         4.3             15175
# ...                                        ...         ...               ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3             25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3             25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3             25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2              7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3             15701
#
# ...

# %%
column_to_convert = 'Number of Ratings'
df4[column_to_convert] = df4[column_to_convert].astype(int)
df4
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4                POCO C51 (Power Black, 64 GB)         4.3              15175
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3              25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3              25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3              25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2               7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3              15701
#
# ...

# %%
df4.dtypes
# Out:
# Phone Name            object
# Rating ?/5           float64
# Number of Ratings      int64
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera      object
# Front Camera          object
# Battery               object
# Processor             object
# Price in INR          object
# dtype: object

# %%
df5 = df4.copy()
df5
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4                POCO C51 (Power Black, 64 GB)         4.3              15175
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3              25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3              25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3              25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2               7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3              15701
#
# ...

# %% [markdown]
# **Working on Battery Column**

# %%
df5['Battery'].unique()
# Out:
# array(['5000 mAh', '4500 mAh', '4000 mAh', '5160 mAh', '6000 mAh',
#        '5065 mAh', '4200 mAh', '4300 mAh', '4230 mAh', '3300 mAh',
#        '3900 mAh', '4700 mAh', '3700 mAh', '3000 mAh', '7000 mAh',
#        '4800 mAh', '4015 mAh', '4025 mAh', '3400 mAh', '4350 mAh',
#        '4310 mAh', '3200 mAh', '4020 mAh', '4410 mAh', '4270 mAh',
#        '4926 mAh', '2915 mAh', '4600 mAh', '4030 mAh', '4050 mAh',
#        '4810 mAh', '4830 mAh', '4870 mAh', '4450 mAh', '3315 mAh',
#        '3225 mAh', '3260 mAh', '4250 mAh', '4520 mAh', '3080 mAh',
#        '3120 mAh', '4100 mAh', '4850 mAh', '3030 mAh', '3010 mAh',
#        '4820 mAh', '4780 mAh', '5300 mAh', '5050 mAh', '3060 mAh',
#        '4950 mAh', '4400 mAh', '4610 mAh', '4115 mAh', '3800 mAh',
#        '4085 mAh', '3340 mAh', '3450 mAh', '2150 mAh', '2200 mAh',
#        '2610 mAh', '3760 mAh', '3500 mAh', '5200 mAh'], dtype=object)

# %%
column_to_clean = 'Battery'
df5[column_to_clean] = df5[column_to_clean].str.replace(' mAh', '')
df5
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4                POCO C51 (Power Black, 64 GB)         4.3              15175
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3              25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3              25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3              25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2               7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3              15701
#
# ...

# %%
column_to_convert = 'Battery'
df5[column_to_convert] = df5[column_to_convert].astype(int)
df5
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4                POCO C51 (Power Black, 64 GB)         4.3              15175
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3              25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3              25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3              25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2               7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3              15701
#
# ...

# %%
df5.dtypes
# Out:
# Phone Name            object
# Rating ?/5           float64
# Number of Ratings      int64
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera      object
# Front Camera          object
# Battery                int64
# Processor             object
# Price in INR          object
# dtype: object

# %%
df5.shape
# Out:
# (1272, 10)

# %%
df5.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# dtype: int64

# %% [markdown]
# **WORKING ON Phone Name Column**

# %%
print(df5['Phone Name'].unique())
# Out:
# ['POCO C50 (Royal Blue, 32 GB)' 'POCO M4 5G (Cool Blue, 64 GB)'
#  'POCO C51 (Royal Blue, 64 GB)' ... 'Infinix Note 7 (Aether Black, 64 GB)'
#  'Infinix Zero 8i (Silver Diamond, 128 GB)'
#  'Infinix S5 (Quetzal Cyan, 64 GB)']

# %%
from sklearn.preprocessing import LabelEncoder


data = {'Phone Name': df5['Phone Name'].unique()}
df_label = pd.DataFrame(data)

label_encoder = LabelEncoder()

df_label['Phone Name encoded'] = label_encoder.fit_transform(df_label['Phone Name'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(df_label)
print(label_mapping)
# Out:
#                                     Phone Name  Phone Name encoded
# 0                 POCO C50 (Royal Blue, 32 GB)                 439
# 1                POCO M4 5G (Cool Blue, 64 GB)                 482
# 2                 POCO C51 (Royal Blue, 64 GB)                 441
# 3                  POCO C55 (Cool Blue, 64 GB)                 443
# 4                POCO C51 (Power Black, 64 GB)                 440
# ...                                        ...                 ...
# 1078      Infinix Note 7 (Forest Green, 64 GB)                 104
# 1079      Infinix Note 7 (Bolivia Blue, 64 GB)                 103
# 1080      Infinix Note 7 (Aether Black, 64 GB)                 102
# 1081  Infinix Zero 8i (Silver Diamond, 128 GB)                 143
# 1082          Infinix S5 (Quetzal Cyan, 64 GB)                 105
#
# [1083 rows x 2 columns]
# ...

# %%
category_mapping = label_mapping
df5['Phone Name'] = df5['Phone Name'].map(category_mapping)
df5
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
df5.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# dtype: int64

# %%
df6 = df5.dropna()
df6
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
df6.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# dtype: int64

# %% [markdown]
# **WORKING ON Processor Column**

# %%
data = {'Processor': df6['Processor'].unique()}
df_label = pd.DataFrame(data)

label_encoder = LabelEncoder()

df_label['Processor encoded'] = label_encoder.fit_transform(df_label['Processor'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(df_label)
print(label_mapping)
# Out:
#                                              Processor  Processor encoded
# 0    Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...                106
# 1                     Mediatek Dimensity 700 Processor                 92
# 2                                  Helio G36 Processor                 36
# 3                         Mediatek Helio G85 Processor                112
# 4                         Mediatek Helio G99 Processor                116
# ..                                                 ...                ...
# 224                              Unisoc T616 Processor                225
# 225                       MediaTek Helio A20 Processor                 61
# 226                              UniSoc T610 Processor                216
# 227                       Mediatek Helio G88 Processor                113
# 228                      Helio P22 (MTK6762) Processor                 39
#
# [229 rows x 2 columns]
# ...

# %%
category_mapping = label_mapping
df6['Processor'] = df6['Processor'].map(category_mapping)
df6
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
df6.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# dtype: int64

# %%
df7 = df6.dropna()
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
df7.dtypes
# Out:
# Phone Name             int64
# Rating ?/5           float64
# Number of Ratings      int64
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera      object
# Front Camera          object
# Battery                int64
# Processor              int64
# Price in INR          object
# dtype: object

# %%
column_to_clean = 'Price in INR'
df7[column_to_clean] = df7[column_to_clean].str.replace(',', '')
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
column_to_clean = 'Price in INR'
df7[column_to_clean] = df7[column_to_clean].str.replace('₹', '')
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
column_to_convert = 'Price in INR'
df7[column_to_convert] = df7[column_to_convert].astype(float)
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# ...

# %%
df7.dtypes
# Out:
# Phone Name             int64
# Rating ?/5           float64
# Number of Ratings      int64
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera      object
# Front Camera          object
# Battery                int64
# Processor              int64
# Price in INR         float64
# dtype: object

# %% [markdown]
# **Working on Front Camera Column and Back/Rare Camera**

# %%
data = {'Front Camera': df7['Front Camera'].unique()}
df_label = pd.DataFrame(data)

label_encoder = LabelEncoder()

df_label['Front Camera encoded'] = label_encoder.fit_transform(df_label['Front Camera'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(df_label)
print(label_mapping)
# Out:
#                     Front Camera  Front Camera encoded
# 0               5MP Front Camera                    23
# 1               8MP Front Camera                    28
# 2              16MP Front Camera                     9
# 3              13MP Front Camera                     5
# 4   20MP + 2MP Dual Front Camera                    10
# 5              20MP Front Camera                    11
# 6   32MP + 8MP Dual Front Camera                    16
# 7              32MP Front Camera                    17
# 8   16MP + 8MP Dual Front Camera                     7
# 9              10MP Front Camera                     2
# 10             12MP Front Camera                     3
# 11             25MP Front Camera                    13
# 12  32MP + 2MP Dual Front Camera                    15
# 13  16MP + 2MP Dual Front Camera                     6
# 14        16MP Dual Front Camera                     8
# 15  44MP + 2MP Dual Front Camera                    18
# ...

# %%
category_mapping = label_mapping
df7['Front Camera'] = df7['Front Camera'].map(category_mapping)
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#                          Back/Rare Camera  Front Camera  Battery  Processor  \
# 0                         8MP Dual Camera            23     5000        106
# ...

# %%
data = {'Back/Rare Camera': df7['Back/Rare Camera'].unique()}
df_label = pd.DataFrame(data)

label_encoder = LabelEncoder()

df_label['Back/Rare Camera encoded'] = label_encoder.fit_transform(df_label['Back/Rare Camera'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(df_label)
print(label_mapping)
# Out:
#                                Back/Rare Camera  Back/Rare Camera encoded
# 0                               8MP Dual Camera                       142
# 1                                    50MP + 2MP                        97
# 2                          8MP Dual Rear Camera                       143
# 3                         50MP Dual Rear Camera                       116
# 4    50MP + 2MP Depth Sensor + 2MP Macro Sensor                       102
# ..                                          ...                       ...
# 140                     13MP + Low Light Sensor                        40
# 141                         13MP + Depth Sensor                        39
# 142           48MP + 2MP + 2MP + AI Lens Camera                        67
# 143           48MP + 8MP + 2MP + AI Lens Camera                        75
# 144         16MP + 5MP + 2MP + Low Light Sensor                        48
#
# [145 rows x 2 columns]
# ...

# %%
category_mapping = label_mapping
df7['Back/Rare Camera'] = df7['Back/Rare Camera'].map(category_mapping)
df7
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#       Back/Rare Camera  Front Camera  Battery  Processor  Price in INR
# 0                  142            23     5000        106        5649.0
# ...

# %%
df7.dtypes
# Out:
# Phone Name             int64
# Rating ?/5           float64
# Number of Ratings      int64
# RAM                    int64
# ROM/Storage            int64
# Back/Rare Camera       int64
# Front Camera           int64
# Battery                int64
# Processor              int64
# Price in INR         float64
# dtype: object

# %%
df7.isnull().sum()
# Out:
# Phone Name           0
# Rating ?/5           0
# Number of Ratings    0
# RAM                  0
# ROM/Storage          0
# Back/Rare Camera     0
# Front Camera         0
# Battery              0
# Processor            0
# Price in INR         0
# dtype: int64

# %% [markdown]
# **MODEL BUILDING**

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
X = df7.iloc[:, :-1]
y = df7['Price in INR']

# %%
X
# Out:
#       Phone Name  Rating ?/5  Number of Ratings  RAM  ROM/Storage  \
# 0            439         4.2              33561    2           32
# 1            482         4.2              77128    4           64
# 2            441         4.3              15175    4           64
# 3            443         4.2              22621    4           64
# 4            440         4.3              15175    4           64
# ...          ...         ...                ...  ...          ...
# 1831         104         4.3              25582    4           64
# 1832         103         4.3              25582    4           64
# 1833         102         4.3              25582    4           64
# 1834         143         4.2               7117    8          128
# 1835         105         4.3              15701    4           64
#
#       Back/Rare Camera  Front Camera  Battery  Processor
# 0                  142            23     5000        106
# 1                   97            28     5000         92
# ...

# %%
y
# Out:
# 0        5649.0
# 1       11999.0
# 2        6999.0
# 3        7749.0
# 4        6999.0
#          ...
# 1831    14999.0
# 1832    14999.0
# 1833    14999.0
# 1834    18999.0
# 1835    10999.0
# Name: Price in INR, Length: 1272, dtype: float64

# %%
model = LinearRegression()

model.fit(X, y)
predicted_y = model.predict(X)

# %%
coefficients = model.coef_
intercept = model.intercept_
print(f"Coefficients: {coefficients}")
print(f"Intercept: {intercept}")
# Out:
# Coefficients: [-4.71824252e-01 -3.68782368e+01 -6.16975395e-03  1.70324016e+03
#   9.47645224e+01 -3.69654568e+01 -1.34231862e+02 -4.24012973e+00
#  -2.09489339e+00]
# Intercept: 26188.37300126843

# %%
import matplotlib.pyplot as plt

plt.scatter(y, predicted_y)
plt.plot([min(y), max(y)], [min(y), max(y)], linestyle='--', color='red')
plt.xlabel("Actual y")
plt.ylabel("Predicted y")
plt.title("Actual vs. Predicted")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mae = mean_absolute_error(y,predicted_y)
mse = mean_squared_error(y, predicted_y)
rmse = np.sqrt(mse)

print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
# Out:
# Mean Absolute Error (MAE): 5885.252834156729
# Mean Squared Error (MSE): 97099875.84157673
# Root Mean Squared Error (RMSE): 9853.926924915606
